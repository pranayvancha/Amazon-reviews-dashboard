# %%
import pandas as pd
import numpy as np
import json
import gzip

# %%
###Helper function to extract the contents of the zip file
def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        yield eval(l)

# %%
#The below function returns the data in a pandas dataframe. It uses the function
#defined above to extract contents of the zip file.

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %%
true = True
false = False

# %%
#The snippet below is creating an instance of the getDF() function and passing 
#the path of the zip file as an argument to the getDF() function
df = getDF("Toys_and_Games_5.json.gz")

# %%
len(df)
# Out:
# 1828971

# %%
df["vote"].isna().sum()
# Out:
# 1620926

# %%
df["vote"] = df["vote"].dropna()

# %%
df1 = df.dropna()

# %%
len(df1)
# Out:
# 6763

# %%
# return the wordnet object value corresponding to the POS tag
from nltk.corpus import wordnet

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
import nltk
#nltk.download('stopwords')  
#nltk.download('averaged_perceptron_tagger')
#nltk.download('wordnet')
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer

def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)

# clean text data
df1["reviewText_clean"] = df1["reviewText"].apply(lambda x: clean_text(x))
# Out:
# C:\Users\vanch\anaconda3\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1["reviewText_clean"]
# Out:
# 758        great tool teach llustrate financial managemen...
# 1754       even christmas busy cook work car pose fashion...
# 1757       book come damage tha back part unattached henc...
# 1810       love product could anymore satisfied become tr...
# 1823       george elf arrive promptly end november book b...
#                                  ...
# 1825841    great kit help year old nephew put together pa...
# 1826921    wood use ladder average poor production damage...
# 1826983    get xsoul hexblades.....not look good quality ...
# 1827970    soft huggable get bacon daughter christmas pre...
# 1828147    almost give two star bc kid love scheduled pic...
# Name: reviewText_clean, Length: 6763, dtype: object

# %%
# add sentiment anaylsis columns
from nltk.sentiment.vader import SentimentIntensityAnalyzer
#nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
df1["sentiments"] = df1["reviewText_clean"].apply(lambda x: sid.polarity_scores(x))
df1 = pd.concat([df1.drop(['sentiments'], axis=1), df1['sentiments'].apply(pd.Series)], axis=1)
# Out:
# C:\Users\vanch\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df1
# Out:
#          overall vote  verified   reviewTime      reviewerID        asin  \
# 758          5.0   17      True  02 26, 2016  A2374KS5MTBWKI  0972428216
# 1754         5.0    2      True  11 12, 2016  A2O9S0T5KQDSRL  0976990709
# 1757         1.0    2      True  10 21, 2016  A1FO5XIXNQWVBY  0976990709
# 1810         5.0    5      True  01 28, 2016  A34QXH38Z7PV0V  0976990709
# 1823         5.0   12      True  12 29, 2015  A1PMVKG3NE98YF  0976990709
# ...          ...  ...       ...          ...             ...         ...
# 1825841      5.0    2      True  08 21, 2017   AR9S5T80237ZI  B01FKE83MW
# 1826921      1.0    2      True  07 14, 2018   A2F338S8LAKAG  B01G3UI30Y
# 1826983      4.0    5      True   06 2, 2016  A2P216HQVIR2YX  B01G5669KW
# 1827970      1.0    3      True   12 8, 2016   A6CQ1AWMD7J2Y  B01GSYAMWC
# 1828147      1.0    6      True   10 3, 2016  A3VCQ3LXJD78T2  B01GY1BXW2
#
#                              style         reviewerName  \
# 758            {'Format:': ' Toy'}                   QT
# 1754     {'Format:': ' Hardcover'}                Holly
# 1757     {'Format:': ' Hardcover'}                  CGL
# 1810     {'Format:': ' Hardcover'}                 M.W.
# 1823     {'Format:': ' Hardcover'}        ReservoirHogs
# ...                            ...                  ...
# 1825841      {'Color:': ' Silver'}                    M
# 1826921        {'Color:': ' Blue'}  Sebastiaan Sligting
# 1826983       {'Color:': ' Green'}           Jerry Pham
# 1827970       {'Style:': ' Bacon'}           Elyssabeth
# 1828147     {'Size:': ' 50pieces'}       Theresa Streep
#
#                                                 reviewText  \
# 758      Great tool to teach and I llustrate financial ...
# 1754     It's not even Christmas and he has been so bus...
# 1757     Book came damaged! Tha back part was unattache...
# 1810     I LOVE this product. I could not be anymore sa...
# 1823     George the Elf arrived promptly at the end of ...
# ...                                                    ...
# 1825841  Great kit.  Helped my 6 year old nephew put it...
# 1826921  The wood used for this ladder is average to po...
# 1826983  Just got my xsoul hexblades.....not looking so...
# 1827970  WHAT!? This is not soft and huggable AT ALL. I...
# 1828147  I almost gave two stars bc the kids loved it. ...
#
#                                                    summary  unixReviewTime  \
# 758      Great tool to illustrate and teach financial m...      1456444800
# 1754                              How creative you can be!      1478908800
# 1757                                          Damaged book      1477008000
# 1810                                 He's Always Watching!      1453939200
# 1823     George the Elf, Claus Intelligence Agency Oper...      1451347200
# ...                                                    ...             ...
# 1825841            Great experience for first time builder      1503273600
# 1826921                          Seriously disappointed...      1531526400
# 1826983          Questionable....First impression not good      1464825600
# 1827970                         NOT PLUSH OR SOFT/HUGGABLE      1481155200
# 1828147  I scheduled it to be picked up for return imme...      1475452800
#
#                                                      image  \
# 758      [https://images-na.ssl-images-amazon.com/image...
# 1754     [https://images-na.ssl-images-amazon.com/image...
# 1757     [https://images-na.ssl-images-amazon.com/image...
# 1810     [https://images-na.ssl-images-amazon.com/image...
# 1823     [https://images-na.ssl-images-amazon.com/image...
# ...                                                    ...
# 1825841  [https://images-na.ssl-images-amazon.com/image...
# 1826921  [https://images-na.ssl-images-amazon.com/image...
# 1826983  [https://images-na.ssl-images-amazon.com/image...
# 1827970  [https://images-na.ssl-images-amazon.com/image...
# 1828147  [https://images-na.ssl-images-amazon.com/image...
#
#                                           reviewText_clean    neg    neu  \
# 758      great tool teach llustrate financial managemen...  0.000  0.639
# 1754     even christmas busy cook work car pose fashion...  0.244  0.609
# 1757     book come damage tha back part unattached henc...  0.106  0.397
# 1810     love product could anymore satisfied become tr...  0.036  0.685
# 1823     george elf arrive promptly end november book b...  0.037  0.705
# ...                                                    ...    ...    ...
# 1825841  great kit help year old nephew put together pa...  0.079  0.679
# 1826921  wood use ladder average poor production damage...  0.281  0.640
# 1826983  get xsoul hexblades.....not look good quality ...  0.086  0.727
# 1827970  soft huggable get bacon daughter christmas pre...  0.161  0.536
# 1828147  almost give two star bc kid love scheduled pic...  0.097  0.732
#
#            pos  compound
# 758      0.361    0.9836
# 1754     0.147   -0.2263
# 1757     0.497    0.9153
# 1810     0.279    0.9552
# 1823     0.257    0.9836
# ...        ...       ...
# 1825841  0.242    0.9201
# 1826921  0.079   -0.8126
# 1826983  0.187    0.9821
# 1827970  0.304    0.3400
# 1828147  0.170    0.7351
#
# [6763 rows x 17 columns]

# %%
df1.to_csv('reviewText_updated.csv', index = False)
